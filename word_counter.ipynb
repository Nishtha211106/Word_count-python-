# %%
sentence="this is my house and this is my dog"

# %%
splited=sentence.split()

# %%
my_dict={}

# %%
for word in splited:
    if word in my_dict:
        my_dict[word]+=1
    else:
        my_dict[word]=1

# %%
total_items=len(splited)
unique_items=len(my_dict)

# %%
max_value=max(my_dict.values())
#max_key = max(data, key=data.get) to get the key corresponding to max value
#max_key = max(my_dict, key=my_dict.get)

# %%
for word, count in my_dict.items():
  if(count==max_value):
    print(word + ": " + str(count))
# Out:
# this: 2
# is: 2
# my: 2

# %%
print("Total number of items: "+str(total_items))
print("Total number of unique items: "+str(unique_items))
print("The words which appeared max number of times is: ")
for word, count in my_dict.items():
  if(count==max_value):
    print(word + ": " + str(count))
print("They appreared: "+str(max_value)+" times")
print("Words with their count in dictionary")
for word, count in my_dict.items():
  print(word + ": " + str(count))
# Out:
# Total number of items: 9
# Total number of unique items: 6
# The words which appeared max number of times is:
# this: 2
# is: 2
# my: 2
# They appreared: 2 times
# Words with their count in dictionary
# this: 2
# is: 2
# my: 2
# house: 1
# and: 1
# dog: 1
